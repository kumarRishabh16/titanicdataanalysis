# %%
import pandas as pd 
import matplotlib.pyplot

# %%
df= pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.to_string()
# Out:
# '     PassengerId  Survived  Pclass                                                                                Name     Sex    Age  SibSp  Parch              Ticket      Fare            Cabin Embarked\n0              1         0       3                                                             Braund, Mr. Owen Harris    male  22.00      1      0           A/5 21171    7.2500              NaN        S\n1              2         1       1                                 Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.00      1      0            PC 17599   71.2833              C85        C\n2              3         1       3                                                              Heikkinen, Miss. Laina  female  26.00      0      0    STON/O2. 3101282    7.9250              NaN        S\n3              4         1       1                                        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00      1      0              113803   53.1000
# ...

# %%
a=pd.read_csv('titanic.csv', encoding='latin-1')

# %%
a
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Pclass"].value_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-def7b5203a0f> in <module>
# ----> 1 df["Pclass"].value_count()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %%
df['Pcount'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Pcount'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-12604ef85a37> in <module>
# ...

# %%
df["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 19.00    25
#          ..
# 55.50     1
# 74.00     1
# 0.92      1
# 70.50     1
# 12.00     1
# Name: Age, Length: 88, dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
a=df['Sex'].value_counts()

# %%
#what is the number of passengers in each of the cabin classes
df['Age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 19.00    25
#          ..
# 55.50     1
# 74.00     1
# 0.92      1
# 70.50     1
# 12.00     1
# Name: Age, Length: 88, dtype: int64

# %%
a.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
b=df['Survived'].value_counts()

# %%
b.plot()
# Out:
# <AxesSubplot:>

# %%
b.plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Age'].size()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-f646469c6a22> in <module>
# ----> 1 df['Age'].size()
#
# TypeError: 'int' object is not callable

# %%
#how to reshape the layout of tables 
#Titanic data according to the age of the passengers
df.sort_values(by='Age').head()
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 644  0.75      2      1    2666  19.2583   NaN        C
# 469  0.75      2      1    2666  19.2583   NaN        C
# 78   0.83      0      2  248738  29.0000   NaN        S

# %%
#if we want to sort the titanic data according to the cabin class and age in descevding order
df.sort_values(by=['Pclass','Age'], ascending=False).head()
# Out:
#      PassengerId  Survived  Pclass                       Name     Sex   Age  \
# 851          852         0       3        Svensson, Mr. Johan    male  74.0
# 116          117         0       3       Connors, Mr. Patrick    male  70.5
# 280          281         0       3           Duane, Mr. Frank    male  65.0
# 483          484         1       3     Turkula, Mrs. (Hedwig)  female  63.0
# 326          327         0       3  Nysveen, Mr. Johan Hansen    male  61.0
#
#      SibSp  Parch  Ticket    Fare Cabin Embarked
# 851      0      0  347060  7.7750   NaN        S
# 116      0      0  370369  7.7500   NaN        Q
# 280      0      0  336439  7.7500   NaN        Q
# 483      0      0    4134  9.5875   NaN        S
# 326      0      0  345364  6.2375   NaN        S

# %%
df.sort_values(by=['Survived','Age'],ascending=False).head()
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 630          631         1       1       Barkworth, Mr. Algernon Henry Wilson
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 483          484         1       3                     Turkula, Mrs. (Hedwig)
# 570          571         1       2                         Harris, Mr. George
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch       Ticket     Fare Cabin Embarked
# 630    male  80.0      0      0        27042  30.0000   A23        S
# 275  female  63.0      1      0        13502  77.9583    D7        S
# 483  female  63.0      0      0         4134   9.5875   NaN        S
# 570    male  62.0      0      0  S.W./PP 752  10.5000   NaN        S
# 829  female  62.0      0      0       113572  80.0000   B28      NaN

# %%
import pandas as pd
af=pd.read_csv('airquality.csv')

# %%
af
# Out:
#                  datetime  station_antwerp  station_paris  station_london
# 0     2019-05-07 02:00:00              NaN            NaN            23.0
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# 3     2019-05-07 05:00:00              NaN           50.4            16.0
# 4     2019-05-07 06:00:00              NaN           61.9             NaN
# ...                   ...              ...            ...             ...
# 1030  2019-06-20 22:00:00              NaN           21.4             NaN
# 1031  2019-06-20 23:00:00              NaN           24.9             NaN
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
# 1034  2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 4 columns]

# %%
af.head()
# Out:
#               datetime  station_antwerp  station_paris  station_london
# 0  2019-05-07 02:00:00              NaN            NaN            23.0
# 1  2019-05-07 03:00:00             50.5           25.0            19.0
# 2  2019-05-07 04:00:00             45.0           27.7            19.0
# 3  2019-05-07 05:00:00              NaN           50.4            16.0
# 4  2019-05-07 06:00:00              NaN           61.9             NaN

# %%
af.tail()
# Out:
#                  datetime  station_antwerp  station_paris  station_london
# 1030  2019-06-20 22:00:00              NaN           21.4             NaN
# 1031  2019-06-20 23:00:00              NaN           24.9             NaN
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
# 1034  2019-06-21 02:00:00              NaN           20.0             NaN

# %%
af[af['station_paris']>20]
# Out:
#                  datetime  station_antwerp  station_paris  station_london
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# 3     2019-05-07 05:00:00              NaN           50.4            16.0
# 4     2019-05-07 06:00:00              NaN           61.9             NaN
# 5     2019-05-07 07:00:00              NaN           72.4            26.0
# ...                   ...              ...            ...             ...
# 1029  2019-06-20 21:00:00              NaN           25.3             NaN
# 1030  2019-06-20 22:00:00              NaN           21.4             NaN
# 1031  2019-06-20 23:00:00              NaN           24.9             NaN
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
#
# [627 rows x 4 columns]

# %%
a=af[af['station_paris']>25]
sort=a.sort_index().groupby(['station_london']).head()

# %%
sort
# Out:
#                 datetime  station_antwerp  station_paris  station_london
# 2    2019-05-07 04:00:00             45.0           27.7            19.0
# 3    2019-05-07 05:00:00              NaN           50.4            16.0
# 4    2019-05-07 06:00:00              NaN           61.9             NaN
# 5    2019-05-07 07:00:00              NaN           72.4            26.0
# 6    2019-05-07 08:00:00              NaN           77.7            32.0
# ..                   ...              ...            ...             ...
# 916  2019-06-14 06:00:00              NaN           37.9             6.0
# 917  2019-06-14 07:00:00              NaN           49.3            13.0
# 918  2019-06-14 08:00:00              NaN           64.3            11.0
# 919  2019-06-14 09:00:00              NaN           51.5            11.0
# 921  2019-06-14 11:00:00             36.5           27.9            13.0
#
# [217 rows x 4 columns]

# %%
sort.pivot(columns='station_paris', values='datetime')
# Out:
# station_paris 25.1 25.2 25.3 25.6 25.7 25.8 26.0 26.1 26.3 26.4  ... 68.1  \
# 2              NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 3              NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 4              NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 5              NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 6              NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# ..             ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 916            NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 917            NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 918            NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 919            NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
# 921            NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN
#
# station_paris 68.7 71.9                 72.4 74.8 76.8                 77.7  \
# ...

# %%
c=sort.pivot(columns='station_paris')

# %%
c.plot()
# Out:
# <AxesSubplot:>

# %%
c.plot()
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
a=df[df['Age','Pclass']].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Age', 'Pclass')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-0545f720ad4b> in <module>
# ...

# %%
airquality=pd.read_csv('airquality.csv')

# %%
airquality
# Out:
#                  datetime  station_antwerp  station_paris  station_london
# 0     2019-05-07 02:00:00              NaN            NaN            23.0
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# 3     2019-05-07 05:00:00              NaN           50.4            16.0
# 4     2019-05-07 06:00:00              NaN           61.9             NaN
# ...                   ...              ...            ...             ...
# 1030  2019-06-20 22:00:00              NaN           21.4             NaN
# 1031  2019-06-20 23:00:00              NaN           24.9             NaN
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
# 1034  2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 4 columns]

# %%
mean=airquality.groupby(['station_antwerp','station_london'])

# %%
a=mean.mean()
# Out:
#                                 station_paris
# station_antwerp station_london
# 7.5             0.0                      12.4
#                 16.0                     19.1
# 9.0             12.0                     36.9
#                 26.0                     12.6
# 10.0            7.0                      41.0
# ...                                       ...
# 50.5            19.0                     25.0
# 52.5            16.0                     74.8
# 53.0            26.0                     49.8
# 60.5            20.0                     53.1
# 74.5            31.0                     28.8
#
# [87 rows x 1 columns]

# %%
a.head(10)
# Out:
#                datetime  station_antwerp  station_paris  station_london
# 2   2019-05-07 04:00:00             45.0           27.7            19.0
# 3   2019-05-07 05:00:00              NaN           50.4            16.0
# 4   2019-05-07 06:00:00              NaN           61.9             NaN
# 5   2019-05-07 07:00:00              NaN           72.4            26.0
# 6   2019-05-07 08:00:00              NaN           77.7            32.0
# 7   2019-05-07 09:00:00              NaN           67.9            32.0
# 8   2019-05-07 10:00:00              NaN           56.0            28.0
# 9   2019-05-07 11:00:00              NaN           34.5            21.0
# 19  2019-05-07 21:00:00              NaN           26.8            24.0
# 20  2019-05-07 22:00:00              NaN           36.2            24.0

# %%
import pandas as pd
air_quality = pd.read_csv("airquality.csv", parse_dates=True)

# %%
air_quality
# Out:
#                  datetime  station_antwerp  station_paris  station_london
# 0     2019-05-07 02:00:00              NaN            NaN            23.0
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# 3     2019-05-07 05:00:00              NaN           50.4            16.0
# 4     2019-05-07 06:00:00              NaN           61.9             NaN
# ...                   ...              ...            ...             ...
# 1030  2019-06-20 22:00:00              NaN           21.4             NaN
# 1031  2019-06-20 23:00:00              NaN           24.9             NaN
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
# 1034  2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 4 columns]

# %%
air_quality.to_string()
# Out:
# '                 datetime  station_antwerp  station_paris  station_london\n0     2019-05-07 02:00:00              NaN            NaN            23.0\n1     2019-05-07 03:00:00             50.5           25.0            19.0\n2     2019-05-07 04:00:00             45.0           27.7            19.0\n3     2019-05-07 05:00:00              NaN           50.4            16.0\n4     2019-05-07 06:00:00              NaN           61.9             NaN\n5     2019-05-07 07:00:00              NaN           72.4            26.0\n6     2019-05-07 08:00:00              NaN           77.7            32.0\n7     2019-05-07 09:00:00              NaN           67.9            32.0\n8     2019-05-07 10:00:00              NaN           56.0            28.0\n9     2019-05-07 11:00:00              NaN           34.5            21.0\n10    2019-05-07 12:00:00              NaN           20.1            21.0\n11    2019-05-07 13:00:00              NaN           13.0            18.0\n12    2019-05-07 14:00
# ...

# %%
air_quality[["date.utc","station_antwerp","station_paris"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-d1793355f58d> in <module>
# ----> 1 air_quality[["date.utc","station_antwerp","station_paris"]]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ...

# %%
air_quality[["datetime","station_antwerp","station_paris"]]
# Out:
#                  datetime  station_antwerp  station_paris
# 0     2019-05-07 02:00:00              NaN            NaN
# 1     2019-05-07 03:00:00             50.5           25.0
# 2     2019-05-07 04:00:00             45.0           27.7
# 3     2019-05-07 05:00:00              NaN           50.4
# 4     2019-05-07 06:00:00              NaN           61.9
# ...                   ...              ...            ...
# 1030  2019-06-20 22:00:00              NaN           21.4
# 1031  2019-06-20 23:00:00              NaN           24.9
# 1032  2019-06-21 00:00:00              NaN           26.5
# 1033  2019-06-21 01:00:00              NaN           21.8
# 1034  2019-06-21 02:00:00              NaN           20.0
#
# [1035 rows x 3 columns]

# %%
head_airQuality= air_quality[["datetime","station_paris","station_london"]]

# %%
head_airQuality.head(25)
# Out:
#                datetime  station_paris  station_london
# 0   2019-05-07 02:00:00            NaN            23.0
# 1   2019-05-07 03:00:00           25.0            19.0
# 2   2019-05-07 04:00:00           27.7            19.0
# 3   2019-05-07 05:00:00           50.4            16.0
# 4   2019-05-07 06:00:00           61.9             NaN
# 5   2019-05-07 07:00:00           72.4            26.0
# 6   2019-05-07 08:00:00           77.7            32.0
# 7   2019-05-07 09:00:00           67.9            32.0
# 8   2019-05-07 10:00:00           56.0            28.0
# 9   2019-05-07 11:00:00           34.5            21.0
# 10  2019-05-07 12:00:00           20.1            21.0
# 11  2019-05-07 13:00:00           13.0            18.0
# 12  2019-05-07 14:00:00           10.6            20.0
# 13  2019-05-07 15:00:00           13.2            18.0
# 14  2019-05-07 16:00:00           11.0            20.0
# 15  2019-05-07 17:00:00           11.7            20.0
# ...

# %%
head_airQuality.head(25)
# Out:
#   File "<ipython-input-82-73cb86506a51>", line 1
#     head_airQuality.head(1:25)
#                           ^
# SyntaxError: invalid syntax

# %%
combine=pd.concat(['head_airQuality','air_quality'], axis=0 )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-2fdf3fe00d75> in <module>
# ----> 1 combine=pd.concat(['head_airQuality','air_quality'], axis=0 )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     283     ValueError: Indexes have overlapping values: ['a']
#     284     """
# --> 285     op = _Concatenator(
#     286         objs,
#     287         axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     368                     "only Series and DataFrame objs are valid"
#     369                 )
# --> 370                 raise TypeError(msg)
#     371
#     372             # consolidate
#
# ...

# %%
import pandas as pd 
df=pd.read_csv("pokemon.csv")
print(df)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.tostring()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-86-8c134c7d95e6> in <module>
# ----> 1 df.tostring()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'tostring'

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
a1=df[["Name","Attack","Type 1"]]

# %%
a2=df[["Generation"]]

# %%
a1
# Out:
#                       Name  Attack  Generation
# 0                Bulbasaur      49           1
# 1                  Ivysaur      62           1
# 2                 Venusaur      82           1
# 3    VenusaurMega Venusaur     100           1
# 4               Charmander      52           1
# ..                     ...     ...         ...
# 795                Diancie     100           6
# 796    DiancieMega Diancie     160           6
# 797    HoopaHoopa Confined     110           6
# 798     HoopaHoopa Unbound     160           6
# 799              Volcanion     110           6
#
# [800 rows x 3 columns]

# %%
a2
# Out:
#      Generation
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# 795           6
# 796           6
# 797           6
# 798           6
# 799           6
#
# [800 rows x 1 columns]

# %%
a3=pd.concat([a1,a2], axis=0)

# %%
a3.head()
# Out:
#                     Name  Attack  Generation
# 0              Bulbasaur    49.0           1
# 1                Ivysaur    62.0           1
# 2               Venusaur    82.0           1
# 3  VenusaurMega Venusaur   100.0           1
# 4             Charmander    52.0           1

# %%
a3.head(10)
# Out:
#                         Name  Attack  Generation
# 0                  Bulbasaur    49.0           1
# 1                    Ivysaur    62.0           1
# 2                   Venusaur    82.0           1
# 3      VenusaurMega Venusaur   100.0           1
# 4                 Charmander    52.0           1
# 5                 Charmeleon    64.0           1
# 6                  Charizard    84.0           1
# 7  CharizardMega Charizard X   130.0           1
# 8  CharizardMega Charizard Y   104.0           1
# 9                   Squirtle    48.0           1

# %%
print('Shape of the "air_quality" table:',a2.shape)
# Out:
# Shape of the "air_quality" table: (800, 1)

# %%
a1=a1.sort_values('Type 1')

# %%
a1.tail(50)
# Out:
#                       Name  Attack Type 1
# 301                Wingull      30  Water
# 438                 Piplup      51  Water
# 214               Slowking      75  Water
# 541                 Palkia     120  Water
# 210               Quagsire      85  Water
# 641               Ducklett      44  Water
# 642                 Swanna      87  Water
# 140               Gyarados     125  Water
# 139               Magikarp      10  Water
# 653               Frillish      40  Water
# 654              Jellicent      60  Water
# 655              Alomomola      75  Water
# 130                Starmie      75  Water
# 129                 Staryu      45  Water
# 128                Seaking      92  Water
# 127                Goldeen      67  Water
# 126                 Seadra      65  Water
# 125                 Horsea      40  Water
# 107                Kingler     130  Water
# 106                 Krabby     105  Water
# 98                Cloyster      95  Water
# ...

# %%
a1[a1["Name","Type"]=="Electric"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Name', 'Type')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-106-2cb83b6bb883> in <module>
# ...

# %%
pokemon=df.sort_value(by=['Pclass', 'Age']=="Electric")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-1009008b9270> in <module>
# ----> 1 pokemon=df.sort_value(by=['Pclass', 'Age']=="Electric")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sort_value'

# %%
pokemon
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %%
pokemon.head()
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []
